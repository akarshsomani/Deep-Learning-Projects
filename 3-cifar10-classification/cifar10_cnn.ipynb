# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# C:\Users\Akarsh Somani\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=3, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        448
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,294
# Trainable params: 528,294
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=100, epochs=20,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=1,shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/20
# 45000/45000 [==============================] - 18s 399us/step - loss: 1.6343 - acc: 0.4076 - val_loss: 1.2971 - val_acc: 0.5398
#
# Epoch 00001: val_loss improved from inf to 1.29711, saving model to model.weights.best.hdf5
# Epoch 2/20
# 45000/45000 [==============================] - 12s 275us/step - loss: 1.3009 - acc: 0.5322 - val_loss: 1.1400 - val_acc: 0.6038
#
# Epoch 00002: val_loss improved from 1.29711 to 1.14000, saving model to model.weights.best.hdf5
# Epoch 3/20
# 45000/45000 [==============================] - 12s 263us/step - loss: 1.1716 - acc: 0.5831 - val_loss: 1.0425 - val_acc: 0.6240
#
# Epoch 00003: val_loss improved from 1.14000 to 1.04246, saving model to model.weights.best.hdf5
# Epoch 4/20
# 45000/45000 [==============================] - 12s 266us/step - loss: 1.0769 - acc: 0.6166 - val_loss: 0.9874 - val_acc: 0.6460
#
# Epoch 00004: val_loss improved from 1.04246 to 0.98743, saving model to model.weights.best.hdf5
# Epoch 5/20
# 45000/45000 [==============================] - 12s 264us/step - loss: 1.0120 - acc: 0.6405 - val_loss: 0.9164 - val_acc: 0.6730
#
# Epoch 00005: val_loss improved from 0.98743 to 0.91644, saving model to model.weights.best.hdf5
# Epoch 6/20
# 45000/45000 [==============================] - 12s 266us/step - loss: 0.9565 - acc: 0.6600 - val_loss: 0.9264 - val_acc: 0.6744
#
# Epoch 00006: val_loss did not improve from 0.91644
# Epoch 7/20
# 45000/45000 [==============================] - 12s 266us/step - loss: 0.9186 - acc: 0.6742 - val_loss: 0.8564 - val_acc: 0.7010
#
# Epoch 00007: val_loss improved from 0.91644 to 0.85641, saving model to model.weights.best.hdf5
# Epoch 8/20
# 45000/45000 [==============================] - 12s 268us/step - loss: 0.8775 - acc: 0.6905 - val_loss: 0.8491 - val_acc: 0.7004
#
# Epoch 00008: val_loss improved from 0.85641 to 0.84912, saving model to model.weights.best.hdf5
# Epoch 9/20
# 45000/45000 [==============================] - 12s 268us/step - loss: 0.8446 - acc: 0.7017 - val_loss: 0.8133 - val_acc: 0.7206
#
# Epoch 00009: val_loss improved from 0.84912 to 0.81328, saving model to model.weights.best.hdf5
# Epoch 10/20
# 45000/45000 [==============================] - 12s 267us/step - loss: 0.8160 - acc: 0.7115 - val_loss: 0.7879 - val_acc: 0.7202
#
# Epoch 00010: val_loss improved from 0.81328 to 0.78795, saving model to model.weights.best.hdf5
# Epoch 11/20
# 45000/45000 [==============================] - 12s 269us/step - loss: 0.7835 - acc: 0.7218 - val_loss: 0.7688 - val_acc: 0.7262
#
# Epoch 00011: val_loss improved from 0.78795 to 0.76883, saving model to model.weights.best.hdf5
# Epoch 12/20
# 45000/45000 [==============================] - 12s 274us/step - loss: 0.7649 - acc: 0.7314 - val_loss: 0.7556 - val_acc: 0.7322
#
# Epoch 00012: val_loss improved from 0.76883 to 0.75562, saving model to model.weights.best.hdf5
# Epoch 13/20
# 45000/45000 [==============================] - 12s 262us/step - loss: 0.7423 - acc: 0.7381 - val_loss: 0.7361 - val_acc: 0.7436
#
# Epoch 00013: val_loss improved from 0.75562 to 0.73614, saving model to model.weights.best.hdf5
# Epoch 14/20
# 45000/45000 [==============================] - 12s 263us/step - loss: 0.7167 - acc: 0.7477 - val_loss: 0.7443 - val_acc: 0.7398
#
# Epoch 00014: val_loss did not improve from 0.73614
# Epoch 15/20
# 45000/45000 [==============================] - 12s 266us/step - loss: 0.6910 - acc: 0.7562 - val_loss: 0.7221 - val_acc: 0.7402
#
# Epoch 00015: val_loss improved from 0.73614 to 0.72207, saving model to model.weights.best.hdf5
# Epoch 16/20
# 45000/45000 [==============================] - 12s 265us/step - loss: 0.6746 - acc: 0.7636 - val_loss: 0.7224 - val_acc: 0.7510
#
# Epoch 00016: val_loss did not improve from 0.72207
# Epoch 17/20
# 45000/45000 [==============================] - 12s 263us/step - loss: 0.6550 - acc: 0.7681 - val_loss: 0.7242 - val_acc: 0.7464
#
# Epoch 00017: val_loss did not improve from 0.72207
# Epoch 18/20
# 45000/45000 [==============================] - 12s 265us/step - loss: 0.6429 - acc: 0.7721 - val_loss: 0.7014 - val_acc: 0.7516
#
# Epoch 00018: val_loss improved from 0.72207 to 0.70138, saving model to model.weights.best.hdf5
# Epoch 19/20
# 45000/45000 [==============================] - 12s 267us/step - loss: 0.6158 - acc: 0.7818 - val_loss: 0.7050 - val_acc: 0.7504
#
# Epoch 00019: val_loss did not improve from 0.70138
# Epoch 20/20
# 45000/45000 [==============================] - 12s 266us/step - loss: 0.6034 - acc: 0.7846 - val_loss: 0.6861 - val_acc: 0.7614
#
# Epoch 00020: val_loss improved from 0.70138 to 0.68612, saving model to model.weights.best.hdf5

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.7586

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
