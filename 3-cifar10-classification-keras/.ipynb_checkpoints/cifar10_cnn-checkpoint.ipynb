# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# C:\Users\Akarsh Somani\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=100, epochs=20,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=1,shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/20
# 45000/45000 [==============================] - 14s 311us/step - loss: 1.6076 - acc: 0.4152 - val_loss: 1.3095 - val_acc: 0.5372
#
# Epoch 00001: val_loss improved from inf to 1.30947, saving model to model.weights.best.hdf5
# Epoch 2/20
# 45000/45000 [==============================] - 12s 265us/step - loss: 1.2774 - acc: 0.5430 - val_loss: 1.1315 - val_acc: 0.6030
#
# Epoch 00002: val_loss improved from 1.30947 to 1.13152, saving model to model.weights.best.hdf5
# Epoch 3/20
# 45000/45000 [==============================] - 12s 266us/step - loss: 1.1437 - acc: 0.5935 - val_loss: 1.0578 - val_acc: 0.6332
#
# Epoch 00003: val_loss improved from 1.13152 to 1.05780, saving model to model.weights.best.hdf5
# Epoch 4/20
# 45000/45000 [==============================] - 12s 267us/step - loss: 1.0596 - acc: 0.6235 - val_loss: 0.9849 - val_acc: 0.6540
#
# Epoch 00004: val_loss improved from 1.05780 to 0.98492, saving model to model.weights.best.hdf5
# Epoch 5/20
# 45000/45000 [==============================] - 12s 267us/step - loss: 0.9813 - acc: 0.6512 - val_loss: 0.9289 - val_acc: 0.6718
#
# Epoch 00005: val_loss improved from 0.98492 to 0.92893, saving model to model.weights.best.hdf5
# Epoch 6/20
# 45000/45000 [==============================] - 12s 264us/step - loss: 0.9228 - acc: 0.6738 - val_loss: 0.8669 - val_acc: 0.6988
#
# Epoch 00006: val_loss improved from 0.92893 to 0.86692, saving model to model.weights.best.hdf5
# Epoch 7/20
# 45000/45000 [==============================] - 12s 266us/step - loss: 0.8671 - acc: 0.6934 - val_loss: 0.8299 - val_acc: 0.7034
#
# Epoch 00007: val_loss improved from 0.86692 to 0.82988, saving model to model.weights.best.hdf5
# Epoch 8/20
# 45000/45000 [==============================] - 12s 266us/step - loss: 0.8166 - acc: 0.7125 - val_loss: 0.8052 - val_acc: 0.7214
#
# Epoch 00008: val_loss improved from 0.82988 to 0.80523, saving model to model.weights.best.hdf5
# Epoch 9/20
# 45000/45000 [==============================] - 12s 265us/step - loss: 0.7741 - acc: 0.7265 - val_loss: 0.7872 - val_acc: 0.7288
#
# Epoch 00009: val_loss improved from 0.80523 to 0.78724, saving model to model.weights.best.hdf5
# Epoch 10/20
# 45000/45000 [==============================] - 12s 267us/step - loss: 0.7337 - acc: 0.7398 - val_loss: 0.7793 - val_acc: 0.7304
#
# Epoch 00010: val_loss improved from 0.78724 to 0.77934, saving model to model.weights.best.hdf5
# Epoch 11/20
# 45000/45000 [==============================] - 12s 270us/step - loss: 0.6931 - acc: 0.7561 - val_loss: 0.7635 - val_acc: 0.7306
#
# Epoch 00011: val_loss improved from 0.77934 to 0.76348, saving model to model.weights.best.hdf5
# Epoch 12/20
# 45000/45000 [==============================] - 12s 269us/step - loss: 0.6627 - acc: 0.7686 - val_loss: 0.7435 - val_acc: 0.7410
#
# Epoch 00012: val_loss improved from 0.76348 to 0.74350, saving model to model.weights.best.hdf5
# Epoch 13/20
# 45000/45000 [==============================] - 12s 269us/step - loss: 0.6272 - acc: 0.7785 - val_loss: 0.7542 - val_acc: 0.7398
#
# Epoch 00013: val_loss did not improve from 0.74350
# Epoch 14/20
# 45000/45000 [==============================] - 12s 268us/step - loss: 0.5930 - acc: 0.7921 - val_loss: 0.7312 - val_acc: 0.7484
#
# Epoch 00014: val_loss improved from 0.74350 to 0.73116, saving model to model.weights.best.hdf5
# Epoch 15/20
# 45000/45000 [==============================] - 12s 269us/step - loss: 0.5696 - acc: 0.7980 - val_loss: 0.7217 - val_acc: 0.7510
#
# Epoch 00015: val_loss improved from 0.73116 to 0.72170, saving model to model.weights.best.hdf5
# Epoch 16/20
# 45000/45000 [==============================] - 12s 266us/step - loss: 0.5367 - acc: 0.8128 - val_loss: 0.7101 - val_acc: 0.7600
#
# Epoch 00016: val_loss improved from 0.72170 to 0.71015, saving model to model.weights.best.hdf5
# Epoch 17/20
# 45000/45000 [==============================] - 12s 265us/step - loss: 0.5142 - acc: 0.8196 - val_loss: 0.7143 - val_acc: 0.7576
#
# Epoch 00017: val_loss did not improve from 0.71015
# Epoch 18/20
# 45000/45000 [==============================] - 13s 288us/step - loss: 0.4862 - acc: 0.8272 - val_loss: 0.7310 - val_acc: 0.7512
#
# Epoch 00018: val_loss did not improve from 0.71015
# Epoch 19/20
# 45000/45000 [==============================] - 12s 263us/step - loss: 0.4569 - acc: 0.8372 - val_loss: 0.7148 - val_acc: 0.7674
#
# Epoch 00019: val_loss did not improve from 0.71015
# Epoch 20/20
# 45000/45000 [==============================] - 12s 264us/step - loss: 0.4378 - acc: 0.8446 - val_loss: 0.7586 - val_acc: 0.7464
#
# Epoch 00020: val_loss did not improve from 0.71015

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.7469

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
