# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# C:\Users\Akarsh Somani\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=3, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        448
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,294
# Trainable params: 528,294
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=100, epochs=20,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=1,shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/20
# 45000/45000 [==============================] - 18s 403us/step - loss: 1.6600 - acc: 0.3931 - val_loss: 1.3809 - val_acc: 0.5116
#
# Epoch 00001: val_loss improved from inf to 1.38094, saving model to model.weights.best.hdf5
# Epoch 2/20
# 45000/45000 [==============================] - 12s 262us/step - loss: 1.3321 - acc: 0.5236 - val_loss: 1.1889 - val_acc: 0.5806
#
# Epoch 00002: val_loss improved from 1.38094 to 1.18892, saving model to model.weights.best.hdf5
# Epoch 3/20
# 45000/45000 [==============================] - 12s 269us/step - loss: 1.2029 - acc: 0.5708 - val_loss: 1.0869 - val_acc: 0.6194
#
# Epoch 00003: val_loss improved from 1.18892 to 1.08686, saving model to model.weights.best.hdf5
# Epoch 4/20
# 45000/45000 [==============================] - 13s 284us/step - loss: 1.1212 - acc: 0.5978 - val_loss: 1.0956 - val_acc: 0.6212
#
# Epoch 00004: val_loss did not improve from 1.08686
# Epoch 5/20
# 45000/45000 [==============================] - 13s 283us/step - loss: 1.0524 - acc: 0.6266 - val_loss: 0.9794 - val_acc: 0.6558
#
# Epoch 00005: val_loss improved from 1.08686 to 0.97939, saving model to model.weights.best.hdf5
# Epoch 6/20
# 45000/45000 [==============================] - 12s 261us/step - loss: 1.0042 - acc: 0.6448 - val_loss: 0.9223 - val_acc: 0.6782
#
# Epoch 00006: val_loss improved from 0.97939 to 0.92227, saving model to model.weights.best.hdf5
# Epoch 7/20
# 45000/45000 [==============================] - 12s 270us/step - loss: 0.9635 - acc: 0.6567 - val_loss: 0.8899 - val_acc: 0.6932
#
# Epoch 00007: val_loss improved from 0.92227 to 0.88993, saving model to model.weights.best.hdf5
# Epoch 8/20
# 45000/45000 [==============================] - 12s 267us/step - loss: 0.9128 - acc: 0.6776 - val_loss: 0.8560 - val_acc: 0.7072
#
# Epoch 00008: val_loss improved from 0.88993 to 0.85604, saving model to model.weights.best.hdf5
# Epoch 9/20
# 45000/45000 [==============================] - 12s 269us/step - loss: 0.8721 - acc: 0.6920 - val_loss: 0.8433 - val_acc: 0.7098
#
# Epoch 00009: val_loss improved from 0.85604 to 0.84326, saving model to model.weights.best.hdf5
# Epoch 10/20
# 45000/45000 [==============================] - 14s 300us/step - loss: 0.8356 - acc: 0.7048 - val_loss: 0.8421 - val_acc: 0.7108
#
# Epoch 00010: val_loss improved from 0.84326 to 0.84210, saving model to model.weights.best.hdf5
# Epoch 11/20
# 45000/45000 [==============================] - 17s 372us/step - loss: 0.8119 - acc: 0.7129 - val_loss: 0.8314 - val_acc: 0.7118
#
# Epoch 00011: val_loss improved from 0.84210 to 0.83142, saving model to model.weights.best.hdf5
# Epoch 12/20
# 45000/45000 [==============================] - 15s 332us/step - loss: 0.7829 - acc: 0.7240 - val_loss: 0.8101 - val_acc: 0.7212
#
# Epoch 00012: val_loss improved from 0.83142 to 0.81007, saving model to model.weights.best.hdf5
# Epoch 13/20
# 45000/45000 [==============================] - 17s 374us/step - loss: 0.7520 - acc: 0.7347 - val_loss: 0.7878 - val_acc: 0.7264
#
# Epoch 00013: val_loss improved from 0.81007 to 0.78782, saving model to model.weights.best.hdf5
# Epoch 14/20
# 45000/45000 [==============================] - 14s 313us/step - loss: 0.7270 - acc: 0.7440 - val_loss: 0.7685 - val_acc: 0.7294
#
# Epoch 00014: val_loss improved from 0.78782 to 0.76848, saving model to model.weights.best.hdf5
# Epoch 15/20
# 45000/45000 [==============================] - 16s 354us/step - loss: 0.7082 - acc: 0.7528 - val_loss: 0.7735 - val_acc: 0.7320
#
# Epoch 00015: val_loss did not improve from 0.76848
# Epoch 16/20
# 45000/45000 [==============================] - 19s 414us/step - loss: 0.6827 - acc: 0.7581 - val_loss: 0.7414 - val_acc: 0.7418
#
# Epoch 00016: val_loss improved from 0.76848 to 0.74144, saving model to model.weights.best.hdf5
# Epoch 17/20
# 45000/45000 [==============================] - 21s 466us/step - loss: 0.6596 - acc: 0.7671 - val_loss: 0.7562 - val_acc: 0.7420
#
# Epoch 00017: val_loss did not improve from 0.74144
# Epoch 18/20
# 45000/45000 [==============================] - 17s 379us/step - loss: 0.6447 - acc: 0.7723 - val_loss: 0.7355 - val_acc: 0.7410
#
# Epoch 00018: val_loss improved from 0.74144 to 0.73547, saving model to model.weights.best.hdf5
# Epoch 19/20
# 45000/45000 [==============================] - 14s 318us/step - loss: 0.6243 - acc: 0.7767 - val_loss: 0.7313 - val_acc: 0.7522
#
# Epoch 00019: val_loss improved from 0.73547 to 0.73131, saving model to model.weights.best.hdf5
# Epoch 20/20
# 45000/45000 [==============================] - 14s 315us/step - loss: 0.6101 - acc: 0.7818 - val_loss: 0.7369 - val_acc: 0.7534
#
# Epoch 00020: val_loss did not improve from 0.73131

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.7373

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
