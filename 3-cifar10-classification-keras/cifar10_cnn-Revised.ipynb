# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# C:\Users\Akarsh Somani\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
#create and configure agumented image generator
from keras.preprocessing.image import ImageDataGenerator
#randomly shift image horizontally and vertically
datagen=ImageDataGenerator(width_shift_range=0.1,height_shift_range=0.1,horizontal_flip=True)
datagen.fit(x_train)

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit_generator(datagen.flow(x_train, y_train, batch_size=100), steps_per_epoch = x_train.shape[0]//100,
          epochs=20,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=1,shuffle=True)
# Out:
# Epoch 1/20
# 450/450 [==============================] - 24s 53ms/step - loss: 0.8680 - acc: 0.6977 - val_loss: 0.7501 - val_acc: 0.7292
#
# Epoch 00001: val_loss improved from inf to 0.75013, saving model to model.weights.best.hdf5
# Epoch 2/20
# 450/450 [==============================] - 21s 47ms/step - loss: 0.8506 - acc: 0.6998 - val_loss: 0.7369 - val_acc: 0.7428
#
# Epoch 00002: val_loss improved from 0.75013 to 0.73685, saving model to model.weights.best.hdf5
# Epoch 3/20
# 450/450 [==============================] - 22s 49ms/step - loss: 0.8268 - acc: 0.7115 - val_loss: 0.7329 - val_acc: 0.7428
#
# Epoch 00003: val_loss improved from 0.73685 to 0.73288, saving model to model.weights.best.hdf5
# Epoch 4/20
# 450/450 [==============================] - 22s 49ms/step - loss: 0.8137 - acc: 0.7144 - val_loss: 0.7037 - val_acc: 0.7560
#
# Epoch 00004: val_loss improved from 0.73288 to 0.70373, saving model to model.weights.best.hdf5
# Epoch 5/20
# 450/450 [==============================] - 22s 49ms/step - loss: 0.8048 - acc: 0.7176 - val_loss: 0.6888 - val_acc: 0.7630
#
# Epoch 00005: val_loss improved from 0.70373 to 0.68882, saving model to model.weights.best.hdf5
# Epoch 6/20
# 450/450 [==============================] - 22s 49ms/step - loss: 0.7977 - acc: 0.7166 - val_loss: 0.6950 - val_acc: 0.7588
#
# Epoch 00006: val_loss did not improve from 0.68882
# Epoch 7/20
# 450/450 [==============================] - 22s 49ms/step - loss: 0.7900 - acc: 0.7220 - val_loss: 0.7121 - val_acc: 0.7522
#
# Epoch 00007: val_loss did not improve from 0.68882
# Epoch 8/20
# 450/450 [==============================] - 22s 50ms/step - loss: 0.7788 - acc: 0.7259 - val_loss: 0.6630 - val_acc: 0.7678
#
# Epoch 00008: val_loss improved from 0.68882 to 0.66298, saving model to model.weights.best.hdf5
# Epoch 9/20
# 450/450 [==============================] - 22s 49ms/step - loss: 0.7686 - acc: 0.7289 - val_loss: 0.6984 - val_acc: 0.7598- loss: 0.7691 -
#
# Epoch 00009: val_loss did not improve from 0.66298
# Epoch 10/20
# 450/450 [==============================] - 22s 49ms/step - loss: 0.7533 - acc: 0.7335 - val_loss: 0.6757 - val_acc: 0.7634
#
# Epoch 00010: val_loss did not improve from 0.66298
# Epoch 11/20
# 450/450 [==============================] - 24s 53ms/step - loss: 0.7531 - acc: 0.7341 - val_loss: 0.6965 - val_acc: 0.7564
#
# Epoch 00011: val_loss did not improve from 0.66298
# Epoch 12/20
# 450/450 [==============================] - 24s 53ms/step - loss: 0.7411 - acc: 0.7377 - val_loss: 0.6670 - val_acc: 0.7682
#
# Epoch 00012: val_loss did not improve from 0.66298
# Epoch 13/20
# 450/450 [==============================] - 22s 48ms/step - loss: 0.7284 - acc: 0.7419 - val_loss: 0.6649 - val_acc: 0.7698
#
# Epoch 00013: val_loss did not improve from 0.66298
# Epoch 14/20
# 450/450 [==============================] - 22s 49ms/step - loss: 0.7203 - acc: 0.7469 - val_loss: 0.6561 - val_acc: 0.7674
#
# Epoch 00014: val_loss improved from 0.66298 to 0.65607, saving model to model.weights.best.hdf5
# Epoch 15/20
# 450/450 [==============================] - 22s 50ms/step - loss: 0.7190 - acc: 0.7470 - val_loss: 0.6630 - val_acc: 0.7706
#
# Epoch 00015: val_loss did not improve from 0.65607
# Epoch 16/20
# 450/450 [==============================] - 22s 49ms/step - loss: 0.7179 - acc: 0.7461 - val_loss: 0.6391 - val_acc: 0.7780
#
# Epoch 00016: val_loss improved from 0.65607 to 0.63908, saving model to model.weights.best.hdf5
# Epoch 17/20
# 450/450 [==============================] - 22s 49ms/step - loss: 0.7081 - acc: 0.7500 - val_loss: 0.6122 - val_acc: 0.7878
#
# Epoch 00017: val_loss improved from 0.63908 to 0.61222, saving model to model.weights.best.hdf5
# Epoch 18/20
# 450/450 [==============================] - 22s 49ms/step - loss: 0.6993 - acc: 0.7521 - val_loss: 0.6333 - val_acc: 0.7820
#
# Epoch 00018: val_loss did not improve from 0.61222
# Epoch 19/20
# 450/450 [==============================] - 23s 50ms/step - loss: 0.6962 - acc: 0.7548 - val_loss: 0.6497 - val_acc: 0.7720
#
# Epoch 00019: val_loss did not improve from 0.61222
# Epoch 20/20
# 450/450 [==============================] - 23s 50ms/step - loss: 0.6847 - acc: 0.7579 - val_loss: 0.6275 - val_acc: 0.7806
#
# Epoch 00020: val_loss did not improve from 0.61222

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.7742

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
